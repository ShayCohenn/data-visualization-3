# %% [markdown]
# <a href="https://colab.research.google.com/github/ShayCohenn/data-visualization-3/blob/main/day_76.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df_apps = pd.read_csv('apps.csv')
df_apps = data.dropna()

# %% [markdown]
# How many rows and columns does df_apps have? What are the column names? What does the data look like? Look at a random sample of 5 different rows

# %%
rows = df_apps.shape[0]
columns = df_apps.shape[1]
column_names = list(df_apps.columns)

print(f"{rows = }, {columns = }, {column_names = }")
print(f"sample data: {df_apps.sample(5)}")
# Out:
# rows = 9365, columns = 12, column_names = ['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type', 'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver']
# sample data:                                                     App            Category  \
# 6474  Podcast App: Free & Offline Podcasts by Player FM  NEWS_AND_MAGAZINES
# 4345                                      Break the Egg              FAMILY
# 5391                                          DG Coupon            SHOPPING
# 1690                                     Exam Result BD              FAMILY
# 4578                         101 C Programming Problems              FAMILY
#
#       Rating  Reviews  Size_MBs   Installs  Type Price Content_Rating  \
# 6474     4.6    66384      19.0  1,000,000  Free     0           Teen
# 4345     2.6      366       6.0     50,000  Free     0       Everyone
# 5391     3.7      668       1.1    100,000  Free     0       Everyone
# ...

# %% [markdown]
# Remove the columns called Last_Updated and Android_Version from the DataFrame. We will not use these columns

# %%
df_apps.drop(['Last_Updated', 'Android_Ver'], axis=1, inplace=True)
df_apps.head()
# Out:
#                                                 App Category  Rating  Reviews  \
# 21                              KBA-EZ Health Guide  MEDICAL     5.0        4
# 28                                         Ra Ga Ba     GAME     5.0        2
# 47                                          Mu.F.O.     GAME     5.0        2
# 82                                 Brick Breaker BR     GAME     5.0        7
# 99  Anatomy & Physiology Vocabulary Exam Review App  MEDICAL     5.0        1
#
#     Size_MBs Installs  Type  Price Content_Rating   Genres
# 21      25.0        1  Free      0       Everyone  Medical
# 28      20.0        1  Paid  $1.49       Everyone   Arcade
# 47      16.0        1  Paid  $0.99       Everyone   Arcade
# 82      19.0        5  Free      0       Everyone   Arcade
# 99       4.6        5  Free      0       Everyone  Medical

# %% [markdown]
# Are there any duplicates in data? Check for duplicates using the .duplicated() function. Use .drop_duplicates() to remove any duplicates and create df_apps_clean

# %%
duplicated_rows = df_apps[df_apps.duplicated()]
print(duplicated_rows.shape)
print(duplicated_rows.head())
# Out:
# (476, 10)
#                                              App Category  Rating  Reviews  \
# 946                       420 BZ Budeze Delivery  MEDICAL     5.0        2
# 1133                                 MouseMingle   DATING     2.7        3
# 1196  Cardiac diagnosis (heart rate, arrhythmia)  MEDICAL     4.4        8
# 1231                                Sway Medical  MEDICAL     5.0        3
# 1247              Chat Kids - Chat Room For Kids   DATING     4.7        6
#
#       Size_MBs Installs  Type   Price Content_Rating   Genres
# 946       11.0      100  Free       0     Mature 17+  Medical
# 1133       3.9      100  Free       0     Mature 17+   Dating
# 1196       6.5      100  Paid  $12.99       Everyone  Medical
# 1231      22.0      100  Free       0       Everyone  Medical
# 1247       4.9      100  Free       0     Mature 17+   Dating

# %%
df_apps_clean = df_apps.drop_duplicates(subset=['App', 'Type', 'Price'])
print(df_apps_clean.shape)
df_apps_clean.head()
# Out:
# (8197, 10)
#                                                 App Category  Rating  Reviews  \
# 21                              KBA-EZ Health Guide  MEDICAL     5.0        4
# 28                                         Ra Ga Ba     GAME     5.0        2
# 47                                          Mu.F.O.     GAME     5.0        2
# 82                                 Brick Breaker BR     GAME     5.0        7
# 99  Anatomy & Physiology Vocabulary Exam Review App  MEDICAL     5.0        1
#
#     Size_MBs Installs  Type  Price Content_Rating   Genres
# 21      25.0        1  Free      0       Everyone  Medical
# 28      20.0        1  Paid  $1.49       Everyone   Arcade
# 47      16.0        1  Paid  $0.99       Everyone   Arcade
# 82      19.0        5  Free      0       Everyone   Arcade
# 99       4.6        5  Free      0       Everyone  Medical

# %% [markdown]
# Identify which apps are the highest rated

# %%
df_apps_clean.sort_values('Rating', ascending=False).head()
# Out:
#                                            App   Category  Rating  Reviews  \
# 21                         KBA-EZ Health Guide    MEDICAL     5.0        4
# 1790                          SUMMER SONIC app     EVENTS     5.0        4
# 1769  Yazdani Cd Center EllahAbad Official App     FAMILY     5.0        8
# 985                                DW Security   BUSINESS     5.0        6
# 981                               EU Exit poll  LIFESTYLE     5.0       10
#
#       Size_MBs Installs  Type Price Content_Rating         Genres
# 21        25.0        1  Free     0       Everyone        Medical
# 1790      61.0      500  Free     0       Everyone         Events
# 1769       3.8      500  Free     0       Everyone  Entertainment
# 985       15.0      100  Free     0       Everyone       Business
# 981        9.4      100  Free     0       Everyone      Lifestyle

# %% [markdown]
# What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be a limit in place or can developers make apps as large as they please

# %%
df_apps_clean.sort_values('Size_MBs', ascending=False).head(50)
# Out:
#                                                      App            Category  \
# 9942                      Talking Babsy Baby: Baby Games           LIFESTYLE
# 10687                             Hungry Shark Evolution                GAME
# 9943                               Miami crime simulator                GAME
# 9944                        Gangster Town: Vice District              FAMILY
# 3144                                          Vi Trainer  HEALTH_AND_FITNESS
# 9945                                     Ultimate Tennis              SPORTS
# 7926                                           Post Bank             FINANCE
# 7927                         The Walking Dead: Our World                GAME
# 7928                       Stickman Legends: Shadow Wars                GAME
# 4176    Car Crash III Beam DH Real Damage Simulator 2018                GAME
# 1795                                Navi Radiography Pro             MEDICAL
# ...

# %% [markdown]
# Which apps have the highest number of reviews? Are there any paid apps among the top 50

# %%
df_apps_clean.sort_values('Reviews', ascending=False).head(50)
# Out:
#                                                      App            Category  \
# 10805                                           Facebook              SOCIAL
# 10785                                 WhatsApp Messenger       COMMUNICATION
# 10806                                          Instagram              SOCIAL
# 10784           Messenger – Text and Video Chat for Free       COMMUNICATION
# 10650                                     Clash of Clans                GAME
# 10744            Clean Master- Space Cleaner & Antivirus               TOOLS
# 10835                                     Subway Surfers                GAME
# 10828                                            YouTube       VIDEO_PLAYERS
# 10746  Security Master - Antivirus, VPN, AppLock, Boo...               TOOLS
# 10584                                       Clash Royale                GAME
# 10763                                   Candy Crush Saga                GAME
# ...

# %%
import plotly.express as px

ratings = df_apps_clean.Content_Rating.value_counts()

fig = px.pie(labels=ratings.index, values=ratings.values, title="Content Rating", names=ratings.index,)

fig.update_traces(textposition='outside', textinfo='percent+label')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(labels=ratings.index,
values=ratings.values,
title="Content Rating",
names=ratings.index,
hole=0.6,
)
fig.update_traces(textposition='inside', textfont_size=15, textinfo='percent')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# How many apps had over 1 billion installations? How many apps just had a single install?
#
#
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have to make sure you remove non-numeric characters first

# %%
df_apps_clean['Installs'] = df_apps_clean['Installs'].astype(str).str.replace(',', "")
df_apps_clean['Installs'] = pd.to_numeric(df_apps_clean['Installs'])
df_apps_clean[['App', 'Installs']].groupby('Installs').count()
# Out:
# <ipython-input-72-8e2c1216e694>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-72-8e2c1216e694>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         697
# 5000         425
# 10000        987
# 50000        457
# 100000      1096
# 500000       504
# 1000000     1417
# 5000000      607
# 10000000     933
# ...

# %% [markdown]
# Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.

# %%
df_apps_clean.Price = df_apps_clean.Price.astype(str).str.replace('$', "")
df_apps_clean.Price = pd.to_numeric(df_apps_clean.Price)

df_apps_clean.sort_values('Price', ascending=False).head(20)
# Out:
# <ipython-input-89-9f696e53366f>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-89-9f696e53366f>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                  App   Category  Rating  Reviews   Size_MBs  \
# 3946        I'm Rich - Trump Edition  LIFESTYLE     3.6      275   7.300000
# 3221                  I am Rich Plus     FAMILY     4.0      856   8.700000
# 3554                      💎 I'm rich  LIFESTYLE     3.8      718  26.000000
# ...

# %% [markdown]
# Remove all apps that cost more than $250 from the df_apps_clean DataFrame.

# %%
df_apps_clean = df_apps_clean[df_apps_clean['Price'] < 250]
df_apps_clean.sort_values('Price', ascending=False).head(10)
# Out:
#                                                     App   Category  Rating  \
# 2281                          Vargo Anesthesia Mega App    MEDICAL     4.6
# 1407                                       LTC AS Legal    MEDICAL     4.0
# 2629                                   I am Rich Person  LIFESTYLE     4.2
# 2481                            A Manual of Acupuncture    MEDICAL     3.5
# 4264                            Golfshot Plus: Golf GPS     SPORTS     4.1
# 504                           AP Art History Flashcards     FAMILY     5.0
# 2463                                 PTA Content Master    MEDICAL     4.2
# 2207                                           EMT PASS    MEDICAL     3.4
# 3241  Muscle Premium - Human Anatomy, Kinesiology, B...    MEDICAL     4.2
# 4772   Human Anatomy Atlas 2018: Complete 3D Human Body    MEDICAL     4.5
#
#       Reviews  Size_MBs  Installs  Type  Price Content_Rating     Genres
# ...

# %% [markdown]
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest-grossing paid apps according to this estimate? Out of the top 10, how many are games?

# %%
df_apps_clean['Revenue_Estimate'] = df_apps_clean.Installs.mul(df_apps_clean.Price)
df_apps_clean.sort_values('Revenue_Estimate', ascending=False).head()
# Out:
#                                 App     Category  Rating  Reviews   Size_MBs  \
# 9220                      Minecraft       FAMILY     4.5  2376564  19.000000
# 8825                  Hitman Sniper         GAME     4.6   408292  29.000000
# 7151  Grand Theft Auto: San Andreas         GAME     4.4   348962  26.000000
# 7977        Sleep as Android Unlock    LIFESTYLE     4.5    23966   0.851562
# 7477            Facetune - For Free  PHOTOGRAPHY     4.4    49553  48.000000
#
#       Installs  Type  Price Content_Rating                     Genres  \
# 9220  10000000  Paid   6.99   Everyone 10+  Arcade;Action & Adventure
# 8825  10000000  Paid   0.99     Mature 17+                     Action
# 7151   1000000  Paid   6.99     Mature 17+                     Action
# 7977   1000000  Paid   5.99       Everyone                  Lifestyle
# 7477   1000000  Paid   5.99       Everyone                Photography
#
#       Revenue_Estimate
# 9220        69900000.0
# 8825         9900000.0
# ...

# %%
category_installs = df_apps_clean.groupby('Category').agg({'Installs': pd.Series.sum})
category_installs.sort_values('Installs', ascending=True, inplace=True)

h_bar = px.bar(x = category_installs.Installs,
               y = category_installs.index,
               orientation='h',
               title='Category Popularity')

h_bar.update_layout(xaxis_title='Number of Downloads', yaxis_title='Category')
h_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Create a DataFrame that has the number of apps in one column and the number of installs in another

# %%
cat_number = df_apps_clean.groupby('Category').agg({'App': pd.Series.count})

# %%
category_merged_df = pd.merge(cat_number, category_installs, on='Category', how="inner")
print(f'The dimensions of the DataFrame are: {category_merged_df.shape}')
category_merged_df.sort_values('Installs', ascending=False)
# Out:
# The dimensions of the DataFrame are: (33, 2)
#                       App     Installs
# Category
# GAME                  910  13858762717
# COMMUNICATION         257  11039241530
# TOOLS                 719   8099724500
# PRODUCTIVITY          301   5788070180
# SOCIAL                203   5487841475
# PHOTOGRAPHY           263   4649143130
# FAMILY               1606   4437554490
# VIDEO_PLAYERS         148   3916897200
# TRAVEL_AND_LOCAL      187   2894859300
# NEWS_AND_MAGAZINES    204   2369110650
# ENTERTAINMENT         102   2113660000
# BOOKS_AND_REFERENCE   169   1665791655
# PERSONALIZATION       296   1532341930
# SHOPPING              180   1400331540
# HEALTH_AND_FITNESS    243   1134006220
# SPORTS                260   1096431465
# BUSINESS              262    692018120
# LIFESTYLE             297    503611120
# MAPS_AND_NAVIGATION   118    503267560
# FINANCE               296    455249400
# WEATHER                72    361096500
# ...

# %%
scatter = px.scatter(category_merged_df, # data
                    x='App', # column name
                    y='Installs',
                    title='Category Concentration',
                    size='App',
                    hover_name=category_merged_df.index,
                    color='Installs')

scatter.update_layout(xaxis_title="Number of Apps (Lower=More Concentrated)",
                      yaxis_title="Installs",
                      yaxis=dict(type='log'))

scatter.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values?

# %%
stack = df_apps_clean.Genres.str.split(';', expand=True).stack()
print(f'We now have a single column with shape: {stack.shape}')
num_genres = stack.value_counts()
print(f'Number of genres: {len(num_genres)}')
# Out:
# We now have a single column with shape: (8562,)
# Number of genres: 53

# %%
bar = px.bar(x = num_genres.index[:15],
             y = num_genres.values[:15],
             title='Top Genres',
             hover_name=num_genres.index[:15],
             color=num_genres.values[:15],
             color_continuous_scale='Agsunset')

bar.update_layout(xaxis_title='Genre',
yaxis_title='Number of Apps',
coloraxis_showscale=False)

bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_free_vs_paid = df_apps_clean.groupby(["Category", "Type"], as_index=False).agg({'App': pd.Series.count})
df_free_vs_paid.head()
# Out:
#             Category  Type  App
# 0     ART_AND_DESIGN  Free   58
# 1     ART_AND_DESIGN  Paid    3
# 2  AUTO_AND_VEHICLES  Free   72
# 3  AUTO_AND_VEHICLES  Paid    1
# 4             BEAUTY  Free   42

# %% [markdown]
# Use the plotly express bar chart examples and the .bar() API reference to create a bar chart:

# %%
g_bar = px.bar(df_free_vs_paid,
               x='Category',
               y='App',
               title='Free vs Paid Apps by Category',
               color='Type',
               barmode='group')

g_bar.update_layout(xaxis_title='Category',
                    yaxis_title='Number of Apps',
                    xaxis={'categoryorder':'total descending'},
                    yaxis=dict(type='log'))

g_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?

# %%
box = px.box(df_apps_clean,
             y='Installs',
             x='Type',
             color='Type',
             notched=True,
             points='all',
             title='How Many Downloads are Paid Apps Giving Up?')

box.update_layout(yaxis=dict(type='log'))

box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_paid_apps = df_apps_clean[df_apps_clean['Type'] == 'Paid']
box = px.box(df_paid_apps,
             x='Category',
             y='Revenue_Estimate',
             title='How Much Can Paid Apps Earn?')

box.update_layout(xaxis_title='Category',
                  yaxis_title='Paid App Ballpark Revenue',
                  xaxis={'categoryorder':'min ascending'},
                  yaxis=dict(type='log'))


box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# What is the median price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps

# %%
box = px.box(df_paid_apps,
             x='Category',
             y="Price",
             title='Price per Category')

box.update_layout(xaxis_title='Category',
                  yaxis_title='Paid App Price',
                  xaxis={'categoryorder':'max descending'},
                  yaxis=dict(type='log'))

box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
